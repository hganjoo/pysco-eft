# %%
pwd
# Out:
# '/Users/himanishganjoo/Dropbox/prograceray/pysco-eft/pysco'

# %%
import main
import pandas as pd

# %%
path = '.'

param = pd.Series({
    "theory": "newton",
    "alphaB0": 0.1,
    "alphaM0": 0.5,
    "nthreads": 1,
    "H0": 72,
    "Om_m": 0.25733,
    "T_cmb": 2.726,
    "N_eff": 3.044,
    "w0": -1.0,
    "wa": 0.0,
    "boxlen": 100,
    "ncoarse": 6,
    "npart": 64**3,
    "z_start": 25,
    "seed": 42,
    "position_ICS": "center",
    "fixed_ICS": False,
    "paired_ICS": False,
    "dealiased_ICS": False,
    "power_spectrum_file": f"{path}/pk_lcdmw7v2.dat",
    "initial_conditions": "2LPT",
    "base": f"{path}/t5/",
    "z_out": "[10, 8, 5, 2, 1, 0]",
    "output_snapshot_format": "HDF5",
    "save_power_spectrum": "yes",
    "integrator": "leapfrog",
    "n_reorder": 50,
    "mass_scheme": "TSC",
    "Courant_factor": 1.0,
    "max_aexp_stepping": 10,
    "linear_newton_solver": "multigrid",
    "gradient_stencil_order": 5,
    "Npre": 2,
    "Npost": 1,
    "epsrel": 1e-2,
    "verbose": 1,
    "evolution_table":'no',
    "Om_lambda":0.74
    })

# %%
main.run(param)
# Out:
# param['nthreads']=1
#
# FFT module: NumPy
#
# ----- Compute background cosmology -----
# /opt/anaconda3/lib/python3.12/site-packages/astropy/cosmology/flrw/w0wacdm.py:195: RuntimeWarning: invalid value encountered in scalar divide
#   return zp1 ** (3 * (1 + self._w0 + self._wa)) * exp(-3 * self._wa * z / zp1)
# Write table in: ./t5//evolution_table_pysco_newton_multigrid_ncoarse6.txt
#
# ----- Initial conditions -----
# param['z_start']=25
# Compute 1LPT contribution
# Compute 2LPT contribution
# Write initial snapshot...snap_name='./t5//output_00000/particles_newton_multigrid_ncoarse6.h5'
# param['aexp']=0.038461538461538464 param['t']=array(-15.47501364)
#
# ----- Run N-body -----
# Tables, 13
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00000.dat
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00001.dat
# param['nsteps']=1 param['aexp']=0.04230769237963173 z = 22.636363596172686
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00002.dat
# param['nsteps']=2 param['aexp']=0.04653846162115268 z = 20.48760326760521
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00003.dat
# param['nsteps']=3 param['aexp']=0.05119230768280618 z = 18.53418482706665
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00004.dat
# param['nsteps']=4 param['aexp']=0.05631153852485881 z = 16.758349819523197
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00005.dat
# param['nsteps']=5 param['aexp']=0.06194269232788359 z = 15.143954394275635
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00006.dat
# param['nsteps']=6 param['aexp']=0.06813696155365691 z = 13.676322178125215
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00007.dat
# param['nsteps']=7 param['aexp']=0.07495065783738207 z = 12.342111048173406
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00008.dat
# param['nsteps']=8 param['aexp']=0.08244572387136562 z = 11.129191825160406
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00009.dat
# param['nsteps']=9 param['aexp']=0.0906902960853557 z = 10.026538043925031
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00010.dat
# Snapshot written at ...filename='./t5//output_00001/particles_newton_multigrid_ncoarse6.h5'
# param['aexp']=0.0909090909090909
# param['nsteps']=10 param['aexp']=0.0909090909090909 z = 10.000000000000002
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00011.dat
# param['nsteps']=11 param['aexp']=0.09999999981782201 z = 9.000000018217799
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00012.dat
# param['nsteps']=12 param['aexp']=0.110000000312608 z = 8.090909065073719
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00013.dat
# Snapshot written at ...filename='./t5//output_00002/particles_newton_multigrid_ncoarse6.h5'
# param['aexp']=0.11111111111111109
# param['nsteps']=13 param['aexp']=0.11111111111111109 z = 8.000000000000002
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00014.dat
# param['nsteps']=14 param['aexp']=0.12222222282153047 z = 7.1818181416992
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00015.dat
# param['nsteps']=15 param['aexp']=0.13444444578624504 z = 6.438016454691724
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00016.dat
# param['nsteps']=16 param['aexp']=0.14788889017869028 z = 5.7618331491414
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00017.dat
# param['nsteps']=17 param['aexp']=0.162677778971108 z = 5.147121053193151
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00018.dat
# Snapshot written at ...filename='./t5//output_00003/particles_newton_multigrid_ncoarse6.h5'
# param['aexp']=0.16666666666666669
# param['nsteps']=18 param['aexp']=0.16666666666666669 z = 4.999999999999999
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00019.dat
# param['nsteps']=19 param['aexp']=0.18333333390952433 z = 4.454545437402582
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00020.dat
# param['nsteps']=20 param['aexp']=0.20166666763218544 z = 3.9586776622097704
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00021.dat
# param['nsteps']=21 param['aexp']=0.22183333383331816 z = 3.5078887952492446
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00022.dat
# param['nsteps']=22 param['aexp']=0.24401666759818366 z = 3.0980807165462805
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00023.dat
# param['nsteps']=23 param['aexp']=0.2684183337219493 z = 2.7255279329611133
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00024.dat
# param['nsteps']=24 param['aexp']=0.29526016649356307 z = 2.386843582308286
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00025.dat
# param['nsteps']=25 param['aexp']=0.3247861840069178 z = 2.0789487029987104
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00026.dat
# Snapshot written at ...filename='./t5//output_00004/particles_newton_multigrid_ncoarse6.h5'
# param['aexp']=0.3333333333333333
# param['nsteps']=26 param['aexp']=0.3333333333333333 z = 2.0
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00027.dat
# param['nsteps']=27 param['aexp']=0.3666666658249585 z = 1.7272727335333666
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00028.dat
# param['nsteps']=28 param['aexp']=0.40333333144688854 z = 1.4793388545714112
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00029.dat
# param['nsteps']=29 param['aexp']=0.4436666667183756 z = 1.253944402442038
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00030.dat
# param['nsteps']=30 param['aexp']=0.4880333319375424 z = 1.0490403719555332
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00031.dat
# Snapshot written at ...filename='./t5//output_00005/particles_newton_multigrid_ncoarse6.h5' param['aexp']=0.5
# param['nsteps']=31 param['aexp']=0.5 z = 1.0
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00032.dat
# param['nsteps']=32 param['aexp']=0.549999998753266 z = 0.8181818223032529
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00033.dat
# param['nsteps']=33 param['aexp']=0.6049999976221585 z = 0.6528925684798621
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00034.dat
# param['nsteps']=34 param['aexp']=0.6654999955052188 z = 0.5026296119519029
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00035.dat
# param['nsteps']=35 param['aexp']=0.7320499962880332 z = 0.36602691765678097
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00036.dat
# param['nsteps']=36 param['aexp']=0.8052549988996847 z = 0.24184264781518716
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00037.dat
# param['nsteps']=37 param['aexp']=0.885780497666616 z = 0.12894786308150707
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00038.dat
# param['nsteps']=38 param['aexp']=0.9743585466373736 z = 0.026316240003352087
# Write P(k) in ./t5//power/pk_newton_multigrid_ncoarse6_00039.dat
# Snapshot written at ...filename='./t5//output_00006/particles_newton_multigrid_ncoarse6.h5' param['aexp']=1.0
# param['nsteps']=39 param['aexp']=1.0 z = 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.loadtxt('/Users/himanishganjoo/Dropbox/prograceray/pysco-eft/pysco/t5/power/pk_eft_multigrid_ncoarse6_00056.dat')
plt.loglog(x[:,0],x[:,1],'.')

x = np.loadtxt('/Users/himanishganjoo/Dropbox/prograceray/pysco-eft/pysco/t5/power/pk_newton_multigrid_ncoarse6_00039.dat')
plt.loglog(x[:,0],x[:,1],'.')
