# %%
import numpy as np

# %%
from quadratic import *
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from quadratic import *
#
# File ~/Dropbox/prograceray/pysco-eft/pysco/quadratic.py:15
#      12 from numba import config, njit, prange
#      13 import math
# ---> 15 @njit(
#      16     ["f4[:,:,::1](f4[:,:,::1], f4[:,:,::1], f4, f4, f4, f4, f4, f4, f4, f4, f4)"],
#      17     fastmath=True,
#      18     cache=True,
#      19     parallel=True,
#      20 )
#      21 def operator(
#      22     pi: npt.NDArray[np.float32],
#      23     b: npt.NDArray[np.float32],
#      24     h: np.float32,
#      25     C2: np.float32,
#      26     C4: np.float32,
#      27     alphaB: np.float32,
#      28     alphaM: np.float32,
#      29     H: np.float32,
#      30     a: np.float32,
#      31     M: np.float32,
#      32     rhom: np.float32) -> npt.NDArray[np.float32]:
#      33     """Quadratic operator
# ...

# %%
pi = np.zeros((10,10,10))
