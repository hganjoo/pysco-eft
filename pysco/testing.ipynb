# %% [markdown]
# ## Basic functions testing from quadratic.py

# %%
import numpy as np

# %%
from quadratic import *

# %%
ncel = 64

x = np.random.normal(0,10,(ncel,ncel,ncel)).astype(np.float32)
b = np.random.normal(0,10,(ncel,ncel,ncel)).astype(np.float32)

# %%
h = np.float32(1./16)

# %%
C2 = np.float32(-1.5)
C4 = np.float32(0.1)
alphaB = np.float32(0.1)
alphaM = np.float32(0.3)
H = np.float32(1.)
a = np.float32(1.)
M = np.float32(1.)

# %%
res = operator(x,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
ix = np.int32(1)
iy = ix
iz = ix

s1 = solution_quadratic_equation(x,b[ix,iy,iz],ix,iy,iz,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
s1
# Out:
# 0.29026177525520325

# %%
xo = np.copy(x)

# %%
jacobi(x,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
smoothing(xo,b,h,C2,C4,alphaB,alphaM,H,a,M,600)

# %%
x
# Out:
# array([[[ 6.611796  ,  2.755548  , -2.5308566 , ...,  7.615201  ,
#          10.419323  ,  2.6414778 ],
#         [ 3.9567287 ,  1.3290159 ,  6.8973083 , ...,  6.2316046 ,
#           4.030776  , -0.5418774 ],
#         [ 2.0112662 ,  3.0227392 , 11.128209  , ...,  8.12572   ,
#           5.612854  ,  5.4003105 ],
#         ...,
#         [ 8.9403    ,  3.5383925 ,  6.9055295 , ..., 11.667647  ,
#           8.127632  ,  3.25879   ],
#         [ 5.814212  ,  0.41433135,  6.6940613 , ...,  9.947889  ,
#           4.88264   , 13.845016  ],
#         [-1.4929024 ,  7.1530747 ,  4.344763  , ...,  4.156934  ,
#           3.6008625 ,  8.722534  ]],
#
#        [[ 5.370474  ,  9.140543  ,  2.563501  , ...,  7.0289865 ,
#           5.9323354 ,  3.0302966 ],
#         [-2.541978  ,  5.003707  ,  2.3461044 , ..., 12.351959  ,
#          -4.0643945 ,  7.2689095 ],
#         [ 7.1433005 ,  4.0511036 ,  2.881611  , ...,  1.787108  ,
#           8.783301  , -5.6268167 ],
#         ...,
#         [ 2.2063155 ,  6.3748817 ,  6.039962  , ...,  2.878889  ,
#           9.186619  ,  8.865144  ],
#         [ 9.429752  ,  3.2496858 ,  1.566374  , ...,  5.9848485 ,
#           7.5643115 ,  6.3966265 ],
#         [ 4.424909  , -0.8923468 , -0.8331739 , ...,  8.192725  ,
#           5.2716565 ,  6.5830655 ]],
#
#        [[ 7.292873  ,  5.3336167 ,  6.664447  , ..., 10.571615  ,
#           5.062219  ,  3.8278954 ],
#         [-3.510088  ,  5.7232523 ,  0.09070441, ..., -0.7962861 ,
#           4.7710576 , -2.2084072 ],
#         [-4.2885146 , -1.1272734 ,  4.8410583 , ...,  4.263773  ,
#           2.5660765 ,  3.860353  ],
#         ...,
#         [10.371176  ,  7.370907  ,  4.480367  , ..., 17.383581  ,
#          -1.5106452 ,  4.512753  ],
#         [ 5.11269   ,  4.929616  ,  3.9543548 , ...,  3.8599145 ,
#           7.329449  ,  3.4569259 ],
#         [ 3.9042866 , 11.937323  ,  4.3339977 , ...,  4.4799256 ,
#          1.5019006],
#         [1.5221701, 1.5352731, 1.5438478, ..., 1.5713122, 1.5842962,
#          1.507192 ],
#         [1.5259612, 1.5389106, 1.5473132, ..., 1.57535  , 1.5882149,
#          1.5109271],
#         ...,
#         [1.582018 , 1.5922978, 1.5997967, ..., 1.635401 , 1.6496521,
#          1.5697236],
#         [1.5906371, 1.6016508, 1.6094445, ..., 1.643808 , 1.657653 ,
#          1.5777106],
#         [1.5084704, 1.5206102, 1.528996 , ..., 1.5589355, 1.5721589,
#          1.4946926]],
#
#        [[1.5287266, 1.5401728, 1.5481044, ..., 1.5815368, 1.5938127,
#          1.5159193],
#         [1.5325515, 1.5447329, 1.5531917, ..., 1.5853492, 1.5972308,
#          1.5190597],
#         [1.5343289, 1.5470479, 1.556024 , ..., 1.5871077, 1.5988019,
#          1.5202266],
#         ...,
#         [1.593716 , 1.603193 , 1.6103699, ..., 1.649379 , 1.6630946,
#          1.5825589],
#         [1.6034409, 1.6132876, 1.6204097, ..., 1.6590571, 1.6723608,
#          1.5919049],
#         [1.5218381, 1.5324327, 1.5399224, ..., 1.5751092, 1.5877943,
#          1.509831 ]],
#
#        [[1.5374362, 1.547812 , 1.5553391, ..., 1.5936861, 1.6049448,
#          1.5260497],
#         [1.5401931, 1.5518843, 1.5605294, ..., 1.5965203, 1.6072025,
#          1.5277348],
#         [1.5409126, 1.553908 , 1.5637485, ..., 1.5966926, 1.6071577,
#          1.5271924],
#         ...,
#         [1.6022189, 1.6108592, 1.6175554, ..., 1.659987 , 1.6731521,
#          1.5919852],
#         [1.6125946, 1.6213497, 1.6277946, ..., 1.670699 , 1.6833789,
#          1.6022878],
#         [1.5313323, 1.5405715, 1.5472778, ..., 1.5874819, 1.5994338,
#          1.5208102]],
#
#        ...,
#
#        [[1.5638593, 1.5794384, 1.5899162, ..., 1.6098007, 1.6242427,
#          1.5457639],
#         [1.5738789, 1.5893347, 1.5994295, ..., 1.6196414, 1.6340628,
#          1.5557364],
#         [1.5826843, 1.5975441, 1.6069125, ..., 1.6287827, 1.643272 ,
#          1.5648654],
#         ...,
#         [1.6324853, 1.644836 , 1.6531854, ..., 1.6831691, 1.6984941,
#          1.6171937],
#         [1.6389352, 1.6525321, 1.661951 , ..., 1.6892078, 1.7041835,
#          1.622687 ],
#         [1.553385 , 1.5685431, 1.5788488, ..., 1.5997943, 1.6144222,
#          1.5356767]],
#
#        [[1.5779349, 1.5927528, 1.6025616, ..., 1.6250446, 1.6393836,
#          1.5607188],
#         [1.5868924, 1.6015913, 1.6110137, ..., 1.6337358, 1.6480789,
#          1.5696113],
#         [1.594666 , 1.6087056, 1.6174624, ..., 1.6418424, 1.6562332,
#          1.5777035],
#         ...,
#         [1.6470677, 1.6588957, 1.6669235, ..., 1.6987215, 1.713932 ,
#          1.6325101],
#         [1.6538733, 1.6667804, 1.6756684, ..., 1.7051855, 1.7200465,
#          1.6384358],
#         [1.5682758, 1.582614 , 1.5922846, ..., 1.6160424, 1.6304897,
#          1.5515225]],
#
#        [[1.5016007, 1.5159905, 1.5254527, ..., 1.5481596, 1.5618107,
#          1.485206 ],
#         [1.5092415, 1.5236101, 1.5327322, ..., 1.5552094, 1.5689291,
#          1.4925768],
#         [1.5153061, 1.529075 , 1.537524 , ..., 1.5614552, 1.5752134,
#          1.4988959],
#         ...,
#         [1.5680288, 1.5791968, 1.5868546, ..., 1.6189243, 1.6337204,
#          1.5543814],
#         [1.5753878, 1.5876476, 1.5960668, ..., 1.6260813, 1.6404322,
#          1.5609117],
#         [1.492585 , 1.5063295, 1.5155828, ..., 1.5401901, 1.553904 ,
#          1.4768773]]], dtype=float32)

# %%
xn = np.random.rand(16,16,16).astype(np.float32)

# %%
res1 = residual(xn,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
op1 = operator(xn,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
res1[0,0,0]
# Out:
# -859.05853

# %%
op1[0,0,0]
# Out:
# 859.05853

# %%
reserr = residual_error(xn,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
reserr
# Out:
# 334405.75

# %%
terr = truncation_error(xn,b,h,C2,C4,alphaB,alphaM,H,a,M)

# %%
terr
# Out:
# 79485.75

# %%
phi0 = initialise_potential(b,h,C2,alphaB,alphaM,a,M)

# %%
phi0
# Out:
# array([[[-3.14360630e-04, -3.98655393e-04, -3.13039083e-04, ...,
#          -3.40610277e-04, -9.39068923e-05, -4.37979215e-05],
#         [-2.46582873e-04, -4.24688333e-04, -3.88286106e-04, ...,
#          -2.83961144e-05, -2.80011416e-04, -1.60826734e-04],
#         [-5.65444279e-05, -2.00757218e-04, -2.36356369e-04, ...,
#          -1.17547752e-04, -7.74524960e-05, -1.02697937e-04],
#         ...,
#         [-1.82913354e-04, -2.02446143e-04, -3.97964235e-04, ...,
#          -2.07170699e-04, -2.30238526e-04, -1.82500924e-04],
#         [-4.30655316e-04, -2.55116262e-04, -7.70488623e-05, ...,
#          -3.11201817e-04, -1.54897803e-04, -3.28888622e-04],
#         [-2.14818268e-04, -2.94344674e-04, -3.61235172e-04, ...,
#          -3.66624095e-04, -3.08736344e-04, -1.67308797e-04]],
#
#        [[-3.11168958e-04, -2.66370480e-04, -7.77180539e-05, ...,
#          -2.93892575e-04, -3.51389230e-04, -3.23399669e-04],
#         [-4.35457696e-05, -1.90863488e-04, -1.85480952e-04, ...,
#          -4.25933569e-04, -2.18197601e-05, -2.98885192e-04],
#         [-4.11007029e-04, -9.46846994e-05, -1.99144517e-04, ...,
#          -1.45494152e-04, -4.04125283e-04, -3.69624322e-04],
#         ...,
#         [-4.46088052e-05, -3.39916936e-04, -1.34200891e-04, ...,
#          -3.87893349e-04, -3.49899201e-04, -1.41974830e-04],
#         [-3.19521176e-04, -3.15222976e-04, -3.57431330e-04, ...,
#          -3.82272905e-04, -1.49705433e-04, -1.24726546e-04],
#         [-2.36055799e-04, -1.77346097e-04, -6.40231810e-05, ...,
#          -8.07795077e-05, -3.83398699e-04, -1.98523427e-04]],
#
#        [[-1.26861210e-04, -1.30560991e-04, -3.42174812e-04, ...,
#          -2.62825255e-04, -8.20542264e-05, -9.14115662e-05],
#         [-3.71446280e-04, -1.46322971e-04, -2.46147334e-04, ...,
#          -2.56614352e-04, -2.12908068e-04, -3.90858069e-04],
#       dtype=float32)

# %% [markdown]
# ## Additional field testing

# %%
import pandas as pd
import cosmotable
import utils

# %%
param = pd.Series({
    "theory": "eft",
    "alphaB0": 0.1,
    "alphaM0": 0.3,
    "H0": 70.0,
    "Om_m": 0.3,
    "T_cmb": 2.726,
    "N_eff": 3.044,
    "w0": -1.0,
    "wa": 0.0,
    "base": "./",
    "extra": "test",
    "aexp":1,
    "boxlen":100,
    "npart":256**3,
    "compute_additional_field":True,
    "ncoarse":8,
    "Npre":4,
    "Npost":1
    })

# %%
tables = cosmotable.generate(param)
utils.set_units(param)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/astropy/cosmology/flrw/w0wacdm.py:195: RuntimeWarning: invalid value encountered in scalar divide
#   return zp1 ** (3 * (1 + self._w0 + self._wa)) * exp(-3 * self._wa * z / zp1)
# WARNING:root:Write table in: .//evolution_table_pysco_test.txt

# %%
param
# Out:
# theory                                                              eft
# alphaB0                                                             0.1
# alphaM0                                                             0.3
# H0                                                                 70.0
# Om_m                                                                0.3
# T_cmb                                                             2.726
# N_eff                                                             3.044
# w0                                                                 -1.0
# wa                                                                  0.0
# base                                                                 ./
# extra                                                              test
# aexp                                                                  1
# boxlen                                                              100
# npart                                                          16777216
# compute_additional_field                                           True
# ncoarse                                                               8
# Npre                                                                  4
# Npost                                                                 1
# Om_r                                                           0.000085
# Om_lambda                                                      0.699915
# unit_l                                         4408110830701953155072.0
# unit_t                                             440811083070195264.0
# unit_d                                                              0.0
# mpart                       14097092043396121045439115753951766511616.0
# dtype: object

# %%
import eftcalcs

# %%
eft_quantities = eftcalcs.geteft(param,tables)

# %%
potential = np.empty(0, dtype=np.float32)
density = np.random.normal(0,10,(256,256,256)).astype(np.float32)
h = 1./256

param["alphaB"] = eft_quantities[0]
param["alphaM"] = eft_quantities[1]
param["C2"] = eft_quantities[2]
param["C4"] = eft_quantities[3]
param["H"] = eft_quantities[4]
param["M"] = eft_quantities[5]

# %%
import solver

# %%
phi = solver.initialise_potential(potential,density,h,param,tables)

# %%
phi = solver.get_additional_field(phi,density,h,param,tables)
# Out:
# [0.09999999999999999, 0.3, 1.1930805152998332, 0.2, 0.9999999999999999, 0.9672311250534926]
# Mean chi: 0, dens: -1.0002e+00, stdev: 9.9973e+00
# op111: 8.7361e-05

# %% [markdown]
# ### initialise_potential and get_additional_field work: 13 Jan 25

# %%
phi.shape
# Out:
# (256, 256, 256)

# %%
phi
# Out:
# array([[[10.434296 , 10.43681  , 10.435273 , ..., 10.435791 ,
#          10.435626 , 10.436086 ],
#         [10.436256 , 10.434516 , 10.437109 , ..., 10.436857 ,
#          10.435017 , 10.436183 ],
#         [10.435895 , 10.435483 , 10.435841 , ..., 10.435246 ,
#          10.436396 , 10.435314 ],
#         ...,
#         [10.435275 , 10.437291 , 10.435706 , ..., 10.435466 ,
#          10.435054 , 10.437675 ],
#         [10.436435 , 10.43568  , 10.435018 , ..., 10.436432 ,
#          10.436882 , 10.435058 ],
#         [10.436623 , 10.434699 , 10.4368105, ..., 10.43555  ,
#          10.435502 , 10.435559 ]],
#
#        [[10.43701  , 10.435647 , 10.4361   , ..., 10.435248 ,
#          10.43589  , 10.434634 ],
#         [10.435212 , 10.436853 , 10.435337 , ..., 10.435937 ,
#          10.4354105, 10.435938 ],
#         [10.435553 , 10.436063 , 10.435933 , ..., 10.43697  ,
#          10.435967 , 10.435845 ],
#         ...,
#         [10.436793 , 10.435085 , 10.435571 , ..., 10.435349 ,
#          10.436941 , 10.4345875],
#         [10.434922 , 10.436325 , 10.436376 , ..., 10.436014 ,
#          10.435882 , 10.436854 ],
#         [10.434778 , 10.436819 , 10.436679 , ..., 10.434886 ,
#          10.435285 , 10.43574  ]],
#
#        [[10.435213 , 10.436107 , 10.4360485, ..., 10.433974 ,
#          10.435566 , 10.435674 ],
#         [10.436233 , 10.436055 , 10.436442 , ..., 10.436712 ,
#          10.435155 , 10.434953 ],
#         [10.435439 , 10.434733 , 10.436127 , ..., 10.435948 ,
#          10.436523 , 10.435232 ],
#         ...,
#         [10.434732 , 10.4368515, 10.43657  , ..., 10.437085 ,
#          10.43675  , 10.43662  ],
#         [10.4359045, 10.435606 , 10.434651 , ..., 10.436485 ,
#          10.436281 , 10.435753 ],
#         [10.436331 , 10.435112 , 10.435829 , ..., 10.436284 ,
#          10.436022 , 10.43573  ]],
#
#        ...,
#
#        [[10.435752 , 10.435604 , 10.436826 , ..., 10.436428 ,
#          10.435215 , 10.436688 ],
#         [10.436955 , 10.43629  , 10.434736 , ..., 10.4363   ,
#          10.435686 , 10.436377 ],
#         [10.436168 , 10.435156 , 10.436367 , ..., 10.435676 ,
#          10.434991 , 10.436291 ],
#         ...,
#         [10.43544  , 10.436517 , 10.436355 , ..., 10.4365425,
#          10.4369135, 10.435117 ],
#         [10.43691  , 10.4347725, 10.435316 , ..., 10.436623 ,
#          10.436471 , 10.436463 ],
#         [10.436054 , 10.4352665, 10.4355   , ..., 10.436472 ,
#          10.435645 , 10.435587 ]],
#
#        [[10.437346 , 10.436077 , 10.435126 , ..., 10.436976 ,
#          10.43675  , 10.435702 ],
#         [10.436527 , 10.435534 , 10.437239 , ..., 10.436687 ,
#          10.435097 , 10.436636 ],
#         [10.436642 , 10.435948 , 10.435932 , ..., 10.434408 ,
#          10.436993 , 10.435702 ],
#         ...,
#         [10.436115 , 10.4358015, 10.435577 , ..., 10.436472 ,
#          10.434792 , 10.436961 ],
#         [10.436164 , 10.435133 , 10.435645 , ..., 10.436769 ,
#          10.435818 , 10.435578 ],
#         [10.434999 , 10.435453 , 10.435763 , ..., 10.435374 ,
#          10.436175 , 10.435729 ]],
#
#        [[10.436436 , 10.435171 , 10.437148 , ..., 10.435794 ,
#          10.4354105, 10.436768 ],
#         [10.436911 , 10.436701 , 10.435365 , ..., 10.436665 ,
#          10.436952 , 10.435563 ],
#         [10.435292 , 10.435878 , 10.436229 , ..., 10.436636 ,
#          10.4349985, 10.436048 ],
#         ...,
#         [10.437351 , 10.43601  , 10.435227 , ..., 10.435315 ,
#          10.437078 , 10.435442 ],
#         [10.436072 , 10.435596 , 10.435793 , ..., 10.435926 ,
#          10.435976 , 10.436606 ],
#         [10.43614  , 10.435773 , 10.436436 , ..., 10.436354 ,
#          10.435276 , 10.436411 ]]], dtype=float32)
